# %% [markdown]
# ## Import

# %%
import os
import json

from ast import literal_eval

import pandas as pd
import numpy as np

# %% [markdown]
# ## Constant

# %%
RAW_DIR = '../data/raw'
RAW_PATH = os.path.join(RAW_DIR, 'wiki_edits.json')

PROCESSED_DIR = '../data/processed'
PROCESSED_PATH = os.path.join(PROCESSED_DIR, 'wiki_edits.csv')

# %% [markdown]
# ## Load data

# %%
with open(RAW_PATH) as json_file:
    data = json.load(json_file)

# %%
data_dict = [literal_eval(i.replace(": null", f": {None}").replace(": false", f": {False}").replace(": true", f": {True}")) for i in data]

data = pd.DataFrame(data_dict)
print(len(data))
data.head()
# Out:
# 186430
#   action  change_size flags hashtags  is_anon  is_bot  is_minor  is_new  \
# 0   edit       1441.0  None       []    False   False     False   False
# 1   edit          2.0  None       []    False   False     False   False
# 2   edit         11.0    MB       []    False    True      True   False
# 3   edit         -6.0     M       []    False   False      True   False
# 4   edit          4.0     M       []    False   False      True   False
#
#    is_unpatrolled mentions         ns                          page_title  \
# 0           False       []       User         User:Bluesymamal417/sandbox
# 1           False       []       Main            List of NAIA conferences
# 2           False       []  User talk              User talk:76.64.60.162
# 3           False       []       Main                  Conrad Kennedy III
# 4           False       []   Template  Template:2011–12 in Greek football
#
#   parent_rev_id                                     parsed_summary  \
# 0    1077811974                                               None
# 1    1077811976                                               None
# 2    1077811977  Fixed [[WP:LINT|Lint errors]]. ([[User:Malnada...
# 3    1077811978  v2.04b - Fix errors for [[WP:WCW|CW project]] ...
# 4    1077811979                                               None
#
#        rev_id section                                            summary  \
# 0  1077292551                                                       None
# 1  1077811715                                                       None
# 2   427366561          Fixed [[WP:LINT|Lint errors]]. ([[User:Malnada...
# 3  1073851861          v2.04b - Fix errors for [[WP:WCW|CW project]] ...
# 4  1077811868                                                       None
#
#                                                  url              user geo_ip
# 0  https://en.wikipedia.org/w/index.php?diff=1077...    Bluesymamal417    NaN
# 1  https://en.wikipedia.org/w/index.php?diff=1077...  Santiago Claudio    NaN
# 2  https://en.wikipedia.org/w/index.php?diff=1077...      MalnadachBot    NaN
# 3  https://en.wikipedia.org/w/index.php?diff=1077...           ZI Jony    NaN
# 4  https://en.wikipedia.org/w/index.php?diff=1077...            BEN917    NaN

# %%
data['section'] = data['section'].replace('', np.nan)
data = data.fillna(value=np.nan)

# %% [markdown]
# ## EDA

# %%
data.isnull().mean().sort_values(ascending=True)
# Out:
# action            0.000000
# page_title        0.000000
# ns                0.000000
# user              0.000000
# is_unpatrolled    0.000000
# is_new            0.000000
# mentions          0.000000
# is_bot            0.000000
# is_anon           0.000000
# hashtags          0.000000
# is_minor          0.000000
# change_size       0.100274
# rev_id            0.100274
# url               0.100274
# parent_rev_id     0.125334
# parsed_summary    0.144097
# summary           0.144097
# flags             0.641517
# section           0.725425
# geo_ip            0.867747
# dtype: float64

# %%
print(f'mentions: {(data["mentions"].str.len() == 0).sum()/len(data)}')

print(f'hashtags: {(data["hashtags"].str.len() == 0).sum()/len(data)}')
# Out:
# mentions: 0.9916000643673228
# hashtags: 0.9855119884138819

# %%
categorical_cols=[]
numerical_cols = []
bool_cols = []
for variables in data.columns:
    if data[variables].dtype=='object':
        categorical_cols.append(variables)
    elif data[variables].dtype=='float64':
        numerical_cols.append(variables)
    elif data[variables].dtype=='bool':
        bool_cols.append(variables)
        
print(f'Number of categorical_cols: {len(categorical_cols)}')
print(f'{categorical_cols}')
print('\n')

print(f'Number of numerical_cols: {len(numerical_cols)}')
print(f'{numerical_cols}')
print('\n')

print(f'Number of bool_cols: {len(bool_cols)}')
print(f'{bool_cols}')
print('\n')
# Out:
# Number of categorical_cols: 14
# ['action', 'flags', 'hashtags', 'mentions', 'ns', 'page_title', 'parent_rev_id', 'parsed_summary', 'rev_id', 'section', 'summary', 'url', 'user', 'geo_ip']
#
#
# Number of numerical_cols: 1
# ['change_size']
#
#
# Number of bool_cols: 5
# ['is_anon', 'is_bot', 'is_minor', 'is_new', 'is_unpatrolled']

# %%
for col in data.columns:
    print(f'{col}:\n')
    print(f'{data[col].value_counts()}')
    print(f'\n')
# Out:
# action:
#
# edit             167736
# hit                5825
# block              3270
# create             2915
# patrol             1086
# delete             1063
# reblock            1062
# thank              1053
# move                810
# reviewed            746
# upload              114
# revision             93
# delete_redir         90
# move_redir           90
# approve              81
# tag                  79
# overwrite            71
# protect              53
# byemail              42
# renameuser           37
# insert               36
# create2              18
# autopromote          11
# restore              11
# unprotect             6
# modify                6
# rights                5
# config                4
# unreviewed            3
# unapprove             3
# delete_redir2         2
# unblock               2
# revert                2
# move_prot             2
# reset                 1
# event                 1
# move_stable           1
# Name: action, dtype: int64
#
#
# change_size:
#
#  0.0        11610
#  14.0        6484
# -18.0        4468
#  1.0         3876
#  26.0        3671
#             ...
#  1858.0         1
# -12805.0        1
#  6047.0         1
# -10430.0        1
#  2510.0         1
# Name: change_size, Length: 6353, dtype: int64
#
#
# flags:
#
# MB    28603
# M     27371
# B      6186
# !N     3052
# N      1527
# NB       93
# Name: flags, dtype: int64
#
#
# hashtags:
#
# []                           183729
# [UCB_webform_linked]            816
# [IABot]                         572
# [UCB_toolbar]                   211
# [1]                             211
#                               ...
# [CiteNLM]                         1
# [social]                          1
# [International_relations]         1
# [Transportation]                  1
# [3, 2]                            1
# Name: hashtags, Length: 157, dtype: int64
#
#
# is_anon:
#
# False    161774
# True      24656
# Name: is_anon, dtype: int64
#
#
# is_bot:
#
# False    151548
# True      34882
# Name: is_bot, dtype: int64
#
#
# is_minor:
#
# False    130456
# True      55974
# Name: is_minor, dtype: int64
#
#
# is_new:
#
# False    181758
# True       4672
# Name: is_new, dtype: int64
#
#
# is_unpatrolled:
#
# False    183378
# True       3052
# Name: is_unpatrolled, dtype: int64
#
#
# mentions:
#
# []               184864
# [-]                  92
# [Please]             78
# [You]                66
# [is]                 65
#                   ...
# [he, a, a]            1
# [Correction.]         1
# [family]              1
# [momentum.]           1
# [Speedy]              1
# Name: mentions, Length: 569, dtype: int64
#
#
# ns:
#
# Main              109355
# User talk          25771
# Special            18694
# User                9875
# Project             7585
# Talk                6780
# Draft               2833
# Template            2462
# Category            1145
# Project talk         681
# File                 550
# Draft talk           198
# Template talk        149
# Portal               116
# Category talk         98
# Module                45
# File talk             44
# Module talk           16
# MediaWiki talk        10
# Help                   8
# Help talk              5
# Portal talk            5
# MediaWiki              3
# TimedText              2
# Name: ns, dtype: int64
#
#
# page_title:
#
# Special:Log/abusefilter     5825
# Special:Log/block           4334
# Special:Log/newusers        2975
# Special:Log/delete          1256
# Special:Log/patrol          1086
#                             ...
# Shawnee, Colorado              1
# Çıraklar, Ardeşen              1
# Talk:Mariana Brambilla         1
# User talk:Greenlakes           1
# User talk:81.178.230.193       1
# Name: page_title, Length: 105835, dtype: int64
#
#
# parent_rev_id:
#
# 1077811974    1
# 1078255547    1
# 1078255542    1
# 1078255541    1
# 1078255543    1
#              ..
# 1077875528    1
# 1077875527    1
# 1077875530    1
# 1077875531    1
# 1078312276    1
# Name: parent_rev_id, Length: 163064, dtype: int64
#
#
# parsed_summary:
#
#                                                                                                                                               26424
# Fixed [[WP:LINT|Lint errors]]. ([[User:MalnadachBot/Task 12|Task 12]])                                                                        22716
# Changing short description "Wikipedia list article" to "none" per [[WP:SDNONE]] (via [[de:Benutzer:Schnark/js/bandersnatch|Bandersnatch]])     4206
# Archiving dead bare references                                                                                                                 3472
# New user account                                                                                                                               2915
#                                                                                                                                               ...
# {{[[Template:Dead link|Dead link]]}} tagged 1 [[WP:Bare URLs|bare URL]] ref to 1 dead website: http://www.lahighered.org                          1
# misleading caption (the plant still stands and wasn't demolished but the company went bankrupt)                                                   1
# {{[[Template:Dead link|Dead link]]}} tagged 1 [[WP:Bare URLs|bare URL]] ref to 1 dead website: http://www.orthodoxcanada.net                      1
# Assessment (Start/Low): +banner shell, +Children's literature, +LGBT studies, +Women artists, +Women writers ([[WP:RATER#2.6.4|Rater]])           1
# Closed.  Speedy delete.                                                                                                                           1
# Name: parsed_summary, Length: 60770, dtype: int64
#
#
# rev_id:
#
# 1077854556    2
# 1077865306    2
# 1077868022    2
# 1078283514    2
# 1077853935    2
#              ..
# 1065476830    1
# 1048265812    1
# 1077501116    1
# 1076706827    1
# 552667158     1
# Name: rev_id, Length: 166597, dtype: int64
#
#
# section:
#
# top                                           3671
# External links                                1349
# History                                       1099
# References                                     861
# See also                                       729
#                                               ...
# Connecting services                              1
# Documentaries and films                          1
# Medicagos out of sync                            1
# May 27, 1941 (Tuesday)                           1
# The two world wars and the interwar period       1
# Name: section, Length: 15035, dtype: int64
#
#
# summary:
#
# Fixed [[WP:LINT|Lint errors]]. ([[User:MalnadachBot/Task 12|Task 12]])                                                                                                                                        22716
# Changing short description "Wikipedia list article" to "none" per [[WP:SDNONE]] (via [[de:Benutzer:Schnark/js/bandersnatch|Bandersnatch]])                                                                     4206
# New user account                                                                                                                                                                                               2915
# case fix (via [[WP:JWB]])                                                                                                                                                                                      1130
# /* top */Archiving dead bare references                                                                                                                                                                        1075
#                                                                                                                                                                                                               ...
# moved [[Talk:Pope Leo XIII]] to [[TimedText talk:Pope Leo XIII]]: Moving the article to a TimedText place where I can edit the Article.                                                                           1
# Removing deleted article reference                                                                                                                                                                                1
# Adding local [[Wikipedia:Short description|short description]]: "Former Italian automobile", overriding Wikidata description "former Italian automobile" ([[Wikipedia:Shortdesc helper|Shortdesc helper]])        1
# [[User:Cewbot/log/20210923/configuration|Updating featured articles]]: Swedish (sv) 302/353 FA(s)                                                                                                                 1
# Closed.  Speedy delete.                                                                                                                                                                                           1
# Name: summary, Length: 77484, dtype: int64
#
#
# url:
#
# https://en.wikipedia.org/w/index.php?diff=1077811974&oldid=1077292551    1
# https://en.wikipedia.org/w/index.php?diff=1078255432&oldid=826351046     1
# https://en.wikipedia.org/w/index.php?diff=1078255414&oldid=1078254552    1
# https://en.wikipedia.org/w/index.php?diff=1078255415&oldid=1078038897    1
# https://en.wikipedia.org/w/index.php?diff=1078255416&oldid=1078251308    1
#                                                                         ..
# https://en.wikipedia.org/w/index.php?diff=1077875299&oldid=1077138140    1
# https://en.wikipedia.org/w/index.php?diff=1077875301&oldid=1076724898    1
# https://en.wikipedia.org/w/index.php?diff=1077875302&oldid=1076911572    1
# https://en.wikipedia.org/w/index.php?diff=1077875303&oldid=1077875052    1
# https://en.wikipedia.org/w/index.php?diff=1078312276&oldid=552667158     1
# Name: url, Length: 167736, dtype: int64
#
#
# user:
#
# MalnadachBot                              22716
# Qwerfjkl (bot)                             4222
# ST47ProxyBot                               3987
# Rlink2                                     3477
# BrownHairedGirl                            2738
#                                           ...
# 2601:586:4301:3280:542E:FCFE:F3C9:D849        1
# SASMITA SARANGI                               1
# 212.200.181.197                               1
# Kothottil Karpoorada                          1
# Imonoz                                        1
# Name: user, Length: 24740, dtype: int64
#
#
# geo_ip:
# {'city': None, 'country_name': 'United States', 'latitude': 37.751, 'longitude': -97.822, 'region_name': None}                     1357
# {'city': None, 'country_name': 'United Kingdom', 'latitude': 54.0, 'longitude': -2.0, 'region_name': None}                          389
# {'city': None, 'country_name': 'India', 'latitude': 20.0, 'longitude': 77.0, 'region_name': None}                                   312
# {'city': None, 'country_name': 'United Kingdom', 'latitude': 51.4964, 'longitude': -0.1224, 'region_name': None}                    272
# {'city': 'Athens', 'country_name': 'Greece', 'latitude': 37.9842, 'longitude': 23.7353, 'region_name': 'Attica'}                    156
#                                                                                                                                    ...
# {'city': 'Kimbolton', 'country_name': 'United Kingdom', 'latitude': 52.3325, 'longitude': -0.1844, 'region_name': 'England'}          1
# {'city': 'Houston', 'country_name': 'United States', 'latitude': 29.8636, 'longitude': -95.2054, 'region_name': 'Texas'}              1
# {'city': 'Constantine', 'country_name': 'Algeria', 'latitude': 36.3617, 'longitude': 6.6119, 'region_name': 'Constantine'}            1
# {'city': 'Huntsville', 'country_name': 'United States', 'latitude': 34.7777, 'longitude': -86.5445, 'region_name': 'Alabama'}         1
# {'city': 'Westport', 'country_name': 'United States', 'latitude': 41.1418, 'longitude': -73.3532, 'region_name': 'Connecticut'}       1
# Name: geo_ip, Length: 5107, dtype: int64

# %% [markdown]
# ## Save data

# %%
for col in categorical_cols:
    data[col]=data[col].apply(lambda x: np.nan if x==np.nan else str(x).encode('utf-8', 'replace').decode('utf-8'))

# %%
data.to_csv(PROCESSED_PATH, index = False, encoding='utf-8')
